# %%
print("Rahman Aziz Firmansyah")
# Out:
# Rahman Aziz Firmansyah

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
rating = pd.read_csv('rating_new.csv').drop('Unnamed: 0', axis=1)
rating.head()
# Out:
#    geolocation_lat  geolocation_lng  order_item_id   price  freight_value  \
# 0       -22.927008       -43.230270            1.0  183.00          16.58
# 1       -22.987642       -43.228795            1.0  115.00           0.00
# 2       -22.903826       -43.177436            1.0  144.99          17.28
# 3       -22.881837       -43.358881            1.0   10.00          15.10
# 4        -8.982786       -38.222378            1.0   65.00          25.73
#
#    payment_sequential  payment_installments  payment_value  \
# 0                 1.0                   4.0         199.58
# 1                 1.0                  10.0         115.00
# 2                 1.0                   3.0         162.27
# 3                 1.0                   5.0          50.20
# 4                 1.0                   1.0          90.73
#
#    product_name_lenght  product_description_lenght  ...  order_approved_at  \
# 0                 23.0                       922.0  ...              other
# ...

# %%
rating.isna().sum()
# Out:
# geolocation_lat                    0
# geolocation_lng                    0
# order_item_id                      0
# price                              0
# freight_value                      0
# payment_sequential                 1
# payment_installments               1
# payment_value                      1
# product_name_lenght              192
# product_description_lenght       192
# product_photos_qty               192
# product_weight_g                   5
# product_length_cm                  5
# product_height_cm                  5
# product_width_cm                   5
# label                              0
# customer_city                      0
# customer_state                     0
# geolocation_city                   0
# geolocation_state                  0
# order_status                       0
# order_purchase_timestamp           0
# order_approved_at                  0
# order_delivered_carrier_date       0
# order_delivered_customer_date      0
# ...

# %%
rating.iloc[:, 8:11]
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty
# 0                     23.0                       922.0                 1.0
# 1                     33.0                       523.0                 3.0
# 2                     54.0                       629.0                 1.0
# 3                     30.0                       690.0                 2.0
# 4                     35.0                       534.0                 2.0
# ...                    ...                         ...                 ...
# 13640                 54.0                       427.0                 1.0
# 13641                 54.0                       245.0                 1.0
# 13642                 58.0                       945.0                 1.0
# 13643                  NaN                         NaN                 NaN
# 13644                 60.0                      1957.0                 1.0
#
# [13645 rows x 3 columns]

# %%
df = pd.read_csv('model_development_set.csv')
df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  8b9f55ee19f0356ba6b3f03485e6922d  bc7b9e0d078c0c01f622b38cfcd7ee9c
# 1  5dddbfbf5ba7c90dcb52c18d7835b756  2004ba7732339d9be65f2236d8887ae4
# 2  c7f26440b498a90f758f26eda34f1801  e64711458e5538f51bc01c3388443450
# 3  05e86ce92eb1b627c2296627078d237c  480ca1a9f688a4c482177efdeeb5c3a3
# 4  552215a43eb8963b5ea631bde3e63bc5  dbc6ce0dfea576d88ea65af28d09b69e
#
#    customer_zip_code_prefix   customer_city customer_state  \
# 0                   20521.0  rio de janeiro             RJ
# 1                   22450.0  rio de janeiro             RJ
# 2                   20040.0  rio de janeiro             RJ
# 3                   21330.0  rio de janeiro             RJ
# 4                   56460.0     petrolandia             PE
#
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                      20521.0       -22.927008       -43.230270
# ...

# %%
df.select_dtypes('object').columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_city', 'customer_state',
#        'geolocation_city', 'geolocation_state', 'order_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'product_id', 'seller_id',
#        'shipping_limit_date', 'payment_type', 'product_category_name',
#        'seller_city', 'seller_state', 'product_category_name_english'],
#       dtype='object')

# %%
df['shipping_limit_date'].dtype
# Out:
# dtype('O')
